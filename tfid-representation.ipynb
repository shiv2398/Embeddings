# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Create a CountVectorizer object and fit it to your corpus of text documents
corpus = ["This is the first document",
         'this is the second sentence',
         'this is the second sentence ']
tfid = TfidfVectorizer()
tfid.fit_transform(corpus)
word_matrix=tfid.transform(corpus).toarray()
word_matrix
# Out:
# array([[0.57292883, 0.57292883, 0.338381  , 0.        , 0.        ,
#         0.338381  , 0.338381  ],
#        [0.        , 0.        , 0.3978967 , 0.51236445, 0.51236445,
#         0.3978967 , 0.3978967 ],
#        [0.        , 0.        , 0.3978967 , 0.51236445, 0.51236445,
#         0.3978967 , 0.3978967 ]])

# %%
word_df=pd.DataFrame(word_matrix,columns=vectorizer.get_feature_names())
word_df.head()
# Out:
#    document     first        is    second  sentence       the      this
# 0  0.572929  0.572929  0.338381  0.000000  0.000000  0.338381  0.338381
# 1  0.000000  0.000000  0.397897  0.512364  0.512364  0.397897  0.397897
# 2  0.000000  0.000000  0.397897  0.512364  0.512364  0.397897  0.397897

# %%
# Create heatmap using seaborn
sns.heatmap(word_matrix, cmap='Blues', annot=True, xticklabels=vectorizer.get_feature_names())
plt.title("CountVectorizer Heatmap")
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
